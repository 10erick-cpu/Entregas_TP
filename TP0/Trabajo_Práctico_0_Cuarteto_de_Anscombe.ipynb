# %% [markdown]
# <a href="https://colab.research.google.com/github/10erick-cpu/Entregas_TP/blob/main/TP0/Trabajo_Pr%C3%A1ctico_0_Cuarteto_de_Anscombe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Trabajo Practico 0 - Cuarteto de Anscombe**

# %% [markdown]
# ### **Alumno** : Erick Macote Yparraguirre
# ### **mail** : leonelerick59@gmail.com
# ### **Profesor** : Ing. Manlio Miguel Massiris

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Librerias Usadas**

# %%
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd

# %% [markdown]
# #**Cuarteto de Anscombe**#

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**Supongamos que tenemos 4 nuevos datos**:
#
# **[16,8]**
#
# **[8,6]**
#
# **[16,10]**
#
# **[16,6]**
#
# ###Sabemos que cada uno corresponde a un único dataset. Sin embargo, los parámetros estadísticos de los 4 datasets son idénticos (ver debajo). ¿ Cómo determinar entonces a qué dataset corresponde cada punto? .

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**Generamos el Dataset (csv) - Cuarteto de Anscombe**

# %%
df = pd.read_csv("Dataset Cuarteto de Anscombe.csv",sep=';')
df
# Out:
#     X1     Y1  X2    Y2  X3     Y3  X4     Y4
# 0   10   8.04  10  9.14  10   7.46   8   6.58
# 1    8   6.95   8  8.14   8   6.77   8   5.76
# 2   13   7.58  13  8.74  13  12.74   8   7.71
# 3    9   8.81   9  8.77   9   7.11   8   8.84
# 4   11   8.33  11  9.26  11   7.81   8   8.47
# 5   14   9.96  14  8.10  14   8.84   8   7.04
# 6    6   7.24   6  6.13   6   6.08   8   5.25
# 7    4   4.26   4  3.10   4   5.39  19  12.50
# 8   12  10.84  12  9.13  12   8.15   8   5.56
# 9    7   4.82   7  7.26   7   6.42   8   7.91
# 10   5   5.68   5  4.74   5   5.73   8   6.89

# %% [markdown]
# #**Obtenemos los parametros Estadisticos**

# %%
df.describe()
# Out:
#               X1         Y1         X2         Y2         X3         Y3  \
# count  11.000000  11.000000  11.000000  11.000000  11.000000  11.000000
# mean    9.000000   7.500909   9.000000   7.500909   9.000000   7.500000
# std     3.316625   2.031568   3.316625   2.031657   3.316625   2.030424
# min     4.000000   4.260000   4.000000   3.100000   4.000000   5.390000
# 25%     6.500000   6.315000   6.500000   6.695000   6.500000   6.250000
# 50%     9.000000   7.580000   9.000000   8.140000   9.000000   7.110000
# 75%    11.500000   8.570000  11.500000   8.950000  11.500000   7.980000
# max    14.000000  10.840000  14.000000   9.260000  14.000000  12.740000
#
#               X4         Y4
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.030579
# min     8.000000   5.250000
# 25%     8.000000   6.170000
# 50%     8.000000   7.040000
# 75%     8.000000   8.190000
# max    19.000000  12.500000

# %% [markdown]
# #**Análisis Grafico**

# %% [markdown]
# 1.   Procedemos a realizar los gráficos de los 4 datasets,  Y = f(x) .
# 2.   Luego evaluamos los 4 nuevos datos, para saber  que puntos de esos datos se corresponden con cada dataset del cuarteto de Anscombe.

# %% [markdown]
# #**Datos nuevos a verificar**

# %%
new_values_x = [16,8,16,16]
new_values_y = [8,6,10,6]

# %% [markdown]
# #**Gráficos**

# %% [markdown]
# # **Gráfico - Dataset I**

# %%
df1 = pd.read_csv("Dataset Cuarteto de Anscombe.csv",usecols = ['X1','Y1'],sep=';')

x = np.array(df1['X1'])
y = np.array(df1['Y1'])


plt.figure(figsize=(10,7.5))
plt.plot(x,y,'go',label='Dataset - I')
plt.plot(new_values_x,new_values_y,'bo',label='Datos a verificar')


plt.grid()
plt.xlabel('X1',fontsize=12)
plt.ylabel('Y1',fontsize=12)
plt.title('Cuarteto de Anscombe - Dataset I',fontsize=15)
plt.legend( loc='lower right',fontsize=15)


# ax = plt.gca()
# ax.set_facecolor('white')

plt.show()

# %% [markdown]
# # **Conclusión** :
#
# ####Según gráfico se deduce que el punto (dato nuevo) a verificar :
#
#
# new_value_1 = (16,8)   pertenece al Dataset I

# %% [markdown]
# # **Gráfico - Dataset II**

# %%
df2 = pd.read_csv("Dataset Cuarteto de Anscombe.csv",usecols = ['X2','Y2'],sep=';')

x = np.array(df2['X2'])
y = np.array(df2['Y2'])


plt.figure(figsize=(10,7.5))
plt.plot(x,y,'go',label='Dataset - II')
plt.plot(new_values_x,new_values_y,'bo',label='Datos a verificar')


plt.grid()
plt.xlabel('X2',fontsize=12)
plt.ylabel('Y2',fontsize=12)
plt.title('Cuarteto de Anscombe - Dataset II',fontsize=15)
plt.legend( loc='lower right',fontsize=15)


# ax = plt.gca()
# ax.set_facecolor('white')

plt.show()

# %% [markdown]
# # **Conclusión** :
#
# ####Según gráfico se deduce que el punto (dato nuevo) a verificar :
#
#
# new_value_4 = (16,6)   pertenece al Dataset II

# %% [markdown]
# # **Gráfico - Dataset III**

# %%
df3 = pd.read_csv("Dataset Cuarteto de Anscombe.csv",usecols = ['X3','Y3'],sep=';')

x = np.array(df3['X3'])
y = np.array(df3['Y3'])


plt.figure(figsize=(10,7.5))
plt.plot(x,y,'go',label='Dataset - III')
plt.plot(new_values_x,new_values_y,'bo',label='Datos a verificar')


plt.grid()
plt.xlabel('X3',fontsize=12)
plt.ylabel('Y3',fontsize=12)
plt.title('Cuarteto de Anscombe - Dataset III',fontsize=15)
plt.legend( loc='lower right',fontsize=15)


# ax = plt.gca()
# ax.set_facecolor('white')

plt.show()

# %% [markdown]
# # **Conclusión** :
#
# ####Según gráfico se deduce que el punto (dato nuevo) a verificar :
#
#
# new_value_3 = (16,10)   pertenece al Dataset III

# %% [markdown]
# # **Gráfico - Dataset IV**

# %%
df4 = pd.read_csv("Dataset Cuarteto de Anscombe.csv",usecols = ['X4','Y4'],sep=';')

x = np.array(df4['X4'])
y = np.array(df4['Y4'])


plt.figure(figsize=(10,7.5))
plt.plot(x,y,'go',label='Dataset - IV')
plt.plot(new_values_x,new_values_y,'bo',label='Datos a verificar')


plt.grid()
plt.xlabel('X3',fontsize=12)
plt.ylabel('Y3',fontsize=12)
plt.title('Cuarteto de Anscombe - Dataset IV',fontsize=15)
plt.legend( loc='upper left',fontsize=15)


# ax = plt.gca()
# ax.set_facecolor('white')

plt.show()

# %% [markdown]
# # **Conclusión** :
#
# ####Según gráfico se deduce que el punto (dato nuevo) a verificar :
#
#
# new_value_2 = (8,6)   pertenece al Dataset IV
